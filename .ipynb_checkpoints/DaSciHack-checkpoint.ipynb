# %% [markdown]
# <h1>
#     A Time Series Analysis of the Number of Donors who Fail the Blood Tests
# </h1>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
# %matplotlib inline
sns.set(rc={'figure.figsize':(11, 4)})

# %% [markdown]
# <b>Import data into the DataFrame </b>

# %%
df = pd.read_excel(r'cleaned.xlsx')

# %%
df.head()
# Out:
#    Financial_Year Branch_Code  Sequence_1  Sequence_2 Donation_type  \
# 0              14      BRC-01         345         1.0             R
# 1              14      BRC-01         346         2.0             R
# 2              14      BRC-01         347         3.0             R
# 3              14      BRC-01         348         4.0             R
# 4              14      BRC-01         349         5.0             T
#
#    Donor_Age Donation_Date Gender  Blood_Group_Code  Donor_Weight  \
# 0       24.0     01-JUL-13      M               5.0          56.0
# 1       33.0     01-JUL-13      M               3.0          75.0
# 2       28.0     01-JUL-13      M               5.0          65.0
# 3       20.0     01-JUL-13      M               3.0          65.0
# 4       22.0     01-JUL-13      M               7.0          75.0
#
#    Donor_Temperature  Donor_Pulse  Donor_Hemoglobin Donor_Blood_Pressure  \
# 0               37.0         72.0              13.0               120/80
# ...

# %% [markdown]
# <img src="https://www.dascena.com/hs-fs/hubfs/Bravo%20Website/Images/Blog/Inline/Source%20%E2%80%94%20rn.com.png?width=959&name=Source%20%E2%80%94%20rn.com.png"
#      alt="MEW Text"
#      style="float: left; margin-right: 10px;" />

# %% [markdown]
# # Introducing a new parameter MEW Index in our Model
# We have decided to incorporate the MEW Index as part of an indicator of a healthy vital signs of a blood donor. We can use this measure to predict whether a donor is feasible for donating or not. The criteria for it is given above

# %%
df["MEW_Index"] = 0
# MEW Index  Computation
for idx, rows in df.iterrows():
    temp_sum = 0
    if (df.loc[idx, 'Donor_Temperature'] < 35):
        temp_sum += 2
    elif df.loc[idx, "Donor_Temperature"] < 38.4:
        temp_sum += 0
    else:
        temp_sum += 1
        
    if df.loc[idx, "Donor_Pulse"] <= 40 or (df.loc[idx, "Donor_Pulse"] >= 111 and df.loc[idx, "Donor_Pulse"] < 129):
        temp_sum += 2
    elif df.loc[idx, "Donor_Pulse"] > 41 and df.loc[idx, "Donor_Pulse"] < 50 or (df.loc[idx, "Donor_Pulse"] > 101 and df.loc[idx, "Donor_Pulse"] < 110):
        temp_sum += 1
    elif df.loc[idx, "Donor_Pulse"] > 130:
        temp_sum += 3
    else:
        temp_sum += 0
        
    x = str(df.loc[idx, "Donor_Blood_Pressure"]).split("/")
    
    if int(x[0]) < 70:
        temp_sum += 3
    elif int(x[0]) < 80:
        temp_sum += 2
    elif int(x[0]) < 100:
        temp_sum += 1
    elif int(x[0]) < 199:
        temp_sum += 0
    else:
        temp_sum += 2
        
    # Assume avg. resp rate
    temp_sum += 1
    
    # Assume Normal AVPU Neurological Score
    temp_sum += 2
    
    df.loc[idx, "MEW_Index"] = temp_sum

# %%
df['MEW_Index'].hist()

# %% [markdown]
# We can use this index to check for vital signs.

# %%
df['datetime'] = pd.to_datetime(df['Donation_Date'])

# %%
df = df.set_index('datetime')

# %% [markdown]
# <b color="blue"> Indexing done on the basis of DateTime to ease the process wof querying w.r.t to DT <\b>

# %%
df.index
# Out:
# DatetimeIndex(['2013-07-01', '2013-07-01', '2013-07-01', '2013-07-01',
#                '2013-07-01', '2013-07-01', '2013-07-01', '2013-07-01',
#                '2013-07-01', '2013-07-01',
#                ...
#                '2017-07-07', '2017-07-07', '2017-07-07', '2017-07-12',
#                '2017-07-24', '2017-07-25', '2017-07-26', '2017-07-26',
#                '2017-07-26', '2017-07-26'],
#               dtype='datetime64[ns]', name='datetime', length=225498, freq=None)

# %% [markdown]
# <b> Created a filter for the dates </b>

# %%
mask = (df.index >= '2013-07-01') & (df.index <= '2017-07-26')
df = df.loc[mask]

# %% [markdown]
#  <b> Recoded the test results as follows:
#     P(ositive) and R(eactive have been assigned a value of 1. This marks them as blood samples which might not be suitable for donation. The rest of the values have been recoded to 0, denoting the presence of cases that might be good for donation. </b>

# %%
df.C2.replace(to_replace=dict(P=1, R=1, N=0, I=0), inplace=True)

# %%
df.C1.replace(to_replace=dict(R=1, N=0, I=0), inplace=True)

# %%
df.Test_3.replace(to_replace=dict(P=1, R=1, N=0), inplace=True)

# %%
df.Test_4.replace(to_replace=dict(P=1, R=1, N=0), inplace=True)

# %% [markdown]
# <b> Summed the values across the test results column. Purpose: the higher the value of the 'Test Failed' Column, the lower the preference

# %%
df["Test_Failed"] = 0
df['Test_Failed'] =  df[['C1', 'C2','Test_3','Test_4']].sum(axis=1)

# %% [markdown]
# <b> The plot below shows that most people failed just one of the four tests, with 2 tests being failed being a very rare ocassion. We could not have given any test a higher weightage than the other becasue the dataset masks the true identity of these tests </b>

# %%
df["Test_Failed"].plot()

# %%
y = df['Test_Failed'].resample('MS').mean()

# %% [markdown]
# <b> The seasonal timeseries below shows that the pattern of high peaks repeats itself in the mid of the year, signifying that a  higher proportion of people fail the the different tests, and its during that time, the blood bank has to be more cautious about screening the  blood samples. </b>

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 18, 8
decomposition = sm.tsa.seasonal_decompose(y, model='additive')
fig = decomposition.plot()
plt.show()

# %% [markdown]
# <b> As we can see from the graph above, the seasonal traits seem to fluctuate with a pattern. During the Summer of each season we experience a surge in the amount of failed tests which can telll us a lot about the cost incurred during the blood loss in the Summer Season </b>

# %% [markdown]
# Parameters of the SARIMAX Model:
# <b>p: Trend autoregression order </b>
# <b>d: Trend Difference Order </b>
# <b>q: Trend Moving  Average order </b>

# %%
import itertools

# %%
# Use statistic descriptions as an indicator 
import time
start = time.time()
mod = sm.tsa.statespace.SARIMAX(y,
                                order=(1, 1, 1),
                                seasonal_order=(1, 1, 0, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results = mod.fit()
print(results.summary().tables[1])
end = time.time()
#Time it  took to complete
print("Computation time for model prediction: {}".format(end - start))
# Out:
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.2947      0.426      0.692      0.489      -0.540       1.130
# ma.L1         -0.7295      0.291     -2.507      0.012      -1.300      -0.159
# ar.S.L12      -0.3299      0.165     -2.001      0.045      -0.653      -0.007
# sigma2      2.647e-05   1.07e-05      2.473      0.013    5.49e-06    4.74e-05
# ...
# Computation time for model prediction: 0.7435300350189209
# C:\Users\mmaaz\Anaconda3\lib\site-packages\statsmodels\base\model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)

# %%
results.plot_diagnostics(figsize=(16, 8))
plt.show()

# %%
type(results)
# Out:
# statsmodels.tsa.statespace.sarimax.SARIMAXResultsWrapper

# %%
pred = results.get_prediction(start=pd.to_datetime('2017-02-01'), dynamic=False)
pred_ci = pred.conf_int()
ax = y['2014':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 7))
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date')
ax.set_ylabel('Number of Failed Tests')
plt.legend()
plt.show()

# %% [markdown]
# <b> The Mean-Squared-Error shouldnt have been so small ideally, but provided the fact that the 'Test Failed' column barely had value other than 1 (for reasons described a few cells above), the small value for MSE makes sense. </b>

# %%
# Calculate the mean difference squared values and use it as a predictor
y_forecasted = pred.predicted_mean
y_truth = y['2017-02-01':'2017-07-26']
mse = ((y_forecasted - y_truth) ** 2).mean()
print('The Mean Squared Error of our forecasts is {}'.format(round(mse, 5)))
# Out:
# The Mean Squared Error of our forecasts is 1e-05

# %%
# forecasting for the coming years with confidence intervals

pred_uc = results.get_forecast(steps=100)
pred_ci = pred_uc.conf_int()
ax = y.plot(label='observed', figsize=(14, 7))
pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Date')
ax.set_ylabel('Number of Failed Tests')
plt.legend()
plt.show()

# %% [markdown]
# <b> The End </b>
